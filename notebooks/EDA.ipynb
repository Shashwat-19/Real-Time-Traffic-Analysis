# %% [markdown]
# # Traffic Congestion EDA
#
# Use this notebook for exploratory analysis after collecting data. Production code lives in `src/`.

# %%
from pathlib import Path

import pandas as pd

data_path = Path('../data/raw/traffic_data.csv')
df = pd.read_csv(data_path) if data_path.exists() else pd.DataFrame()
df.head()
